# %%
import pandas as pd
import json
import snscrape.modules.twitter as sntwitter

# %%
def hashscrape(query):    
    # Creating list to append tweet data to
    #tweets_list2 = []
    # MetaData_List = []
    tweetraw=[]
    tweetuser = []
    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
        if i>5000:
            break
        tweetraw.append(tweet)
        tweetuser.append(tweet.user.username)
        # print(type(tweet))
        # tweets_list2.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username,tweet.lang, tweet.likeCount, tweet.retweetCount, tweet.hashtags])
        # MetaData_List.append([tweet.lang, tweet.likeCount, tweet.retweetCount, tweet.hashtags])
    # Creating a dataframe from the tweets list above
    # tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username','Language','Likes', 'Retweets', 'Hashtags'])
    # MetaData = pd.DataFrame(MetaData_List, columns=['Language','Likes', 'Retweets', 'Hashtags'])
    # Combine lists into a dictionary
    tweetrawd = pd.DataFrame(tweetraw)
    tweetuserd = pd.DataFrame(tweetuser)
    rawdata = pd.concat([tweetrawd, tweetuserd], axis=1)
    return rawdata

# %%
query = ['Russia_Ukraine since:2022-02-24 until:2022-02-28',
         'Russia_Ukraine since:2022-03-15 until:2022-03-19',
         'Russia_Ukraine since:2022-03-28 until:2022-04-16',
         'Russia_Ukraine since:2022-09-18 until:2022-09-23',
         'Russia_Ukraine since:2022-10-07 until:2022-10-13',
         'Russia_Ukraine since:2022-11-09 until:2022-11-14',
         'Russia_Ukraine since:2022-12-20 until:2022-12-23',
         'Russia_Ukraine since:2023-02-19 until:2023-02-22',]#'dede since:2023-03-03 until:2023-03-04'

# %%
dfs=[]
for i in range(len(query)):
    dfs.append(hashscrape(query[i]))

# concatenate all dataframes in the list
result = pd.concat(dfs, ignore_index=True)

# %%
result.to_csv('Raw_Tweet_Data.csv', sep=',', index=False)

# %%
TweetData = pd.read_csv('Raw_Tweet_Data.csv')
TweetData.head()
# Out:
# c:\Users\ganes\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                  url  \
# 0  https://twitter.com/NatasaJevtovic/status/1498...
# 1  https://twitter.com/TheRoostergod/status/14980...
# 2  https://twitter.com/34istanbul571/status/14980...
# 3  https://twitter.com/yesliaaaa/status/149808541...
# 4  https://twitter.com/Pagetamil/status/149808540...
#
#                         date  \
# 0  2022-02-27 23:59:43+00:00
# 1  2022-02-27 23:59:38+00:00
# 2  2022-02-27 23:59:34+00:00
# 3  2022-02-27 23:59:30+00:00
# 4  2022-02-27 23:59:27+00:00
#
#                                           rawContent  \
# 0  Ex-Nato head says #Putin wanted to join allian...
# 1  I recommend reading about the first &amp; seco...
# 2  Russia-Ukraine tensions: Latest updates from o...
# 3  Omg, im so sad for him. Happy birthday handsom...
# 4  Russia-Ukraine crisis: 5ஆம் நாள்: சர்வதேச நீதி...
#
#                                      renderedContent                   id  \
# 0  Ex-Nato head says #Putin wanted to join allian...  1498085470374445056
# 1  I recommend reading about the first &amp; seco...  1498085448392007686
# 2  Russia-Ukraine tensions: Latest updates from o...  1498085431770034176
# 3  Omg, im so sad for him. Happy birthday handsom...  1498085415055593479
# 4  Russia-Ukraine crisis: 5ஆம் நாள்: சர்வதேச நீதி...  1498085402594484228
#
#                                                 user  replyCount  \
# 0  {'username': 'NatasaJevtovic', 'id': 489482046...           0
# 1  {'username': 'TheRoostergod', 'id': 4050704716...           0
# 2  {'username': '34istanbul571', 'id': 1451340639...           0
# 3  {'username': 'yesliaaaa', 'id': 494917055, 'di...           0
# 4  {'username': 'Pagetamil', 'id': 2503036010, 'd...           0
#
#    retweetCount  likeCount  quoteCount  ...  inReplyToUser  \
# 0             0          0           0  ...            NaN
# 1             0          1           0  ...            NaN
# 2             0          0           0  ...            NaN
# 3             0          2           0  ...            NaN
# 4             0          0           0  ...            NaN
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'irismarketiq', 'id': 1471155981...         NaN   NaN
# 1                                                NaN         NaN   NaN
# 2  [{'username': 'YouTube', 'id': 10228272, 'disp...         NaN   NaN
# 3                                                NaN         NaN   NaN
# 4                                                NaN         NaN   NaN
#
#                                             hashtags cashtags  \
# 0  ['Putin', 'Nato', 'RussiaUkraine', 'RussiaUkra...      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
#                                                 card  viewCount vibe  \
# 0  {'title': 'Ex-Nato head says Putin wanted to j...        NaN  NaN
# 1                                                NaN        NaN  NaN
# 2  {'title': 'Russia-Ukraine tensions: Latest upd...        NaN  NaN
# 3                                                NaN        NaN  NaN
# 4                                                NaN        NaN  NaN
#
#                 0
# 0  NatasaJevtovic
# 1   TheRoostergod
# 2   34istanbul571
# 3       yesliaaaa
# 4       Pagetamil
#
# [5 rows x 30 columns]
